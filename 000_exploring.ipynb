# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import xpart as xp
import xtrack as xt

fname_model = './generate_models/lhc_at_collisions.json'

nemitt_x = 2.5e-6
nemitt_y = 2.5e-6

collider = xt.Multiline.from_json(fname_model)
collider.build_trackers()
# Out:
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Done loading line from dict.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %% [markdown]
# ## Exploring the LHC
#
# The two beamlines are accessible through `collider.lhcb1` and `collider.lhcb2`. Some examples on how we can access the elements of the lines.
#
# ### Enumerate elements and their names

# %%
collider.lhcb1.element_names  # Element names
# Out:
# ('ip3',
#  'drift_0',
#  'mcbwv.4r3.b1',
#  'drift_1',
#  'bpmw.4r3.b1',
#  'drift_2',
#  'mqwa.a4r3.b1..1',
#  'drift_3',
#  'mqwa.a4r3.b1..2',
#  'drift_4',
#  'mqwa.a4r3.b1',
#  'drift_5',
#  'mqwa.a4r3.b1..3',
#  'drift_6',
#  'mqwa.a4r3.b1..4',
#  'drift_7',
#  'mqwa.b4r3.b1..1',
#  'drift_8',
#  'mqwa.b4r3.b1..2',
#  'drift_9',
#  'mqwa.b4r3.b1',
#  'drift_10',
#  'mqwa.b4r3.b1..3',
#  'drift_11',
#  'mqwa.b4r3.b1..4',
#  'drift_12',
#  'mqwb.4r3.b1..1',
#  'drift_13',
#  'mqwb.4r3.b1..2',
#  'drift_14',
#  'mqwb.4r3.b1',
#  'drift_15',
#  'mqwb.4r3.b1..3',
#  'drift_16',
#  'mqwb.4r3.b1..4',
#  'drift_17',
#  'mqwa.c4r3.b1..1',
#  'drift_18',
#  'mqwa.c4r3.b1..2',
#  'drift_19',
#  'mqwa.c4r3.b1',
#  'drift_20',
#  'mqwa.c4r3.b1..3',
#  'drift_21',
#  'mqwa.c4r3.b1..4',
#  'drift_22',
#  'mqwa.d4r3.b1..1',
#  'drift_23',
#  'mqwa.d4r3.b1..2',
#  'drift_24',
#  'mqwa.d4r3.b1',
#  'drift_25',
#  'mqwa.d4r3.b1..3',
#  'drift_26',
#  'mqwa.d4r3.b1..4',
#  'drift_27',
#  'tcsg.4r3.b1',
#  'drift_28',
#  'mqwa.e4r3.b1..1',
#  'drift_29',
#  'mqwa.e4r3.b1..2',
#  'drift_30',
#  'mqwa.e4r3.b1',
#  'drift_31',
#  'mqwa.e4r3.b1..3',
#  'drift_32',
#  'mqwa.e4r3.b1..4',
#  'drift_33',
#  'bpmwe.4r3.b1',
#  'drift_34',
#  'tcsg.a5r3.b1',
#  'drift_35',
#  'tcsg.b5r3.b1',
#  'drift_36',
#  'tcla.a5r3.b1',
#  'drift_37',
#  'tcla.b5r3.b1',
#  'drift_38',
#  'mcbwh.5r3.b1',
#  'drift_39',
#  'bpmw.5r3.b1',
#  'drift_40',
#  'mqwa.a5r3.b1..1',
#  'drift_41',
#  'mqwa.a5r3.b1..2',
#  'drift_42',
#  'mqwa.a5r3.b1',
#  'drift_43',
#  'mqwa.a5r3.b1..3',
#  'drift_44',
#  'mqwa.a5r3.b1..4',
#  'drift_45',
#  'mqwa.b5r3.b1..1',
#  'drift_46',
#  'mqwa.b5r3.b1..2',
#  'drift_47',
#  'mqwa.b5r3.b1',
#  'drift_48',
#  'mqwa.b5r3.b1..3',
#  'drift_49',
#  'mqwa.b5r3.b1..4',
#  'drift_50',
#  'mqwb.5r3.b1..1',
#  'drift_51',
#  'mqwb.5r3.b1..2',
#  'drift_52',
#  'mqwb.5r3.b1',
#  'drift_53',
#  'mqwb.5r3.b1..3',
#  'drift_54',
#  'mqwb.5r3.b1..4',
#  'drift_55',
#  'mqwa.c5r3.b1..1',
#  'drift_56',
#  'mqwa.c5r3.b1..2',
#  'drift_57',
#  'mqwa.c5r3.b1',
#  'drift_58',
#  'mqwa.c5r3.b1..3',
#  'drift_59',
#  'mqwa.c5r3.b1..4',
#  'drift_60',
#  'mqwa.d5r3.b1..1',
#  'drift_61',
#  'mqwa.d5r3.b1..2',
#  'drift_62',
#  'mqwa.d5r3.b1',
#  'drift_63',
#  'mqwa.d5r3.b1..3',
#  'drift_64',
#  'mqwa.d5r3.b1..4',
#  'drift_65',
#  'mqwa.e5r3.b1..1',
#  'drift_66',
#  'mqwa.e5r3.b1..2',
#  'drift_67',
#  'mqwa.e5r3.b1',
#  'drift_68',
#  'mqwa.e5r3.b1..3',
#  'drift_69',
#  'mqwa.e5r3.b1..4',
#  'drift_70',
#  'bpmwj.a5r3.b1',
#  'drift_71',
#  'mbw.a6r3.b1',
#  'drift_72',
#  'mbw.b6r3.b1',
#  'drift_73',
#  'mbw.c6r3.b1',
#  'drift_74',
#  'tcla.6r3.b1',
#  'drift_75',
#  'mbw.d6r3.b1',
#  'drift_76',
#  'mbw.e6r3.b1',
#  'drift_77',
#  'mbw.f6r3.b1',
#  'drift_78',
#  'bpmwc.6r3.b1',
#  'drift_79',
#  'mcbcv.6r3.b1',
#  'drift_80',
#  'mqtlh.a6r3.b1..1',
#  'drift_81',
#  'mqtlh.a6r3.b1',
#  'drift_82',
#  'mqtlh.a6r3.b1..2',
#  'drift_83',
#  'mqtlh.b6r3.b1..1',
#  'drift_84',
#  'mqtlh.b6r3.b1',
#  'drift_85',
#  'mqtlh.b6r3.b1..2',
#  'drift_86',
#  'mqtlh.c6r3.b1..1',
#  'drift_87',
#  'mqtlh.c6r3.b1',
#  'drift_88',
#  'mqtlh.c6r3.b1..2',
#  'drift_89',
#  'mqtlh.d6r3.b1..1',
#  'drift_90',
#  'mqtlh.d6r3.b1',
#  'drift_91',
#  'mqtlh.d6r3.b1..2',
#  'drift_92',
#  'mqtlh.e6r3.b1..1',
#  'drift_93',
#  'mqtlh.e6r3.b1',
#  'drift_94',
#  'mqtlh.e6r3.b1..2',
#  'drift_95',
#  'mqtlh.f6r3.b1..1',
#  'drift_96',
#  'mqtlh.f6r3.b1',
#  'drift_97',
#  'mqtlh.f6r3.b1..2',
#  'drift_98',
#  'bpmr.6r3.b1',
#  'drift_99',
#  'tcla.7r3.b1',
#  'drift_100',
#  'dfbaf.7r3.b1',
#  'drift_101',
#  'bpm_a.7r3.b1',
#  'drift_102',
#  'mq.7r3.b1..1',
#  'drift_103',
#  'mq.7r3.b1',
#  'drift_104',
#  'mq.7r3.b1..2',
#  'drift_105',
#  'mqtli.7r3.b1..1',
#  'drift_106',
#  'mqtli.7r3.b1',
#  'drift_107',
#  'mqtli.7r3.b1..2',
#  'drift_108',
#  'mcbch.7r3.b1',
#  'drift_109',
#  's.ds.r3.b1',
#  'drift_110',
#  'mco.8r3.b1',
#  'drift_111',
#  'mcd.8r3.b1',
#  'drift_112',
#  'mb.a8r3.b1..1',
#  'drift_113',
#  'mb.a8r3.b1',
#  'drift_114',
#  'mb.a8r3.b1..2',
#  'drift_115',
#  'mcs.a8r3.b1',
#  'drift_116',
#  'mb.b8r3.b1..1',
#  'drift_117',
#  'mb.b8r3.b1',
#  'drift_118',
#  'mb.b8r3.b1..2',
#  'drift_119',
#  'mcs.b8r3.b1',
#  'drift_120',
#  'bpm.8r3.b1',
#  'drift_121',
#  'mq.8r3.b1..1',
#  'drift_122',
#  'mq.8r3.b1',
#  'drift_123',
#  'mq.8r3.b1..2',
#  'drift_124',
#  'mqtli.8r3.b1..1',
#  'drift_125',
#  'mqtli.8r3.b1',
#  'drift_126',
#  'mqtli.8r3.b1..2',
#  'drift_127',
#  'mcbcv.8r3.b1',
#  'drift_128',
#  'mco.9r3.b1',
#  'drift_129',
#  'mcd.9r3.b1',
#  'drift_130',
#  'mb.a9r3.b1..1',
#  'drift_131',
#  'mb.a9r3.b1',
#  'drift_132',
#  'mb.a9r3.b1..2',
#  'drift_133',
#  'mcs.a9r3.b1',
#  'drift_134',
#  'mb.b9r3.b1..1',
#  'drift_135',
#  'mb.b9r3.b1',
#  'drift_136',
#  'mb.b9r3.b1..2',
#  'drift_137',
#  'mcs.b9r3.b1',
#  'drift_138',
#  'bpm.9r3.b1',
#  'drift_139',
#  'mq.9r3.b1..1',
#  'drift_140',
#  'mq.9r3.b1',
#  'drift_141',
#  'mq.9r3.b1..2',
#  'drift_142',
#  'mqtli.a9r3.b1..1',
#  'drift_143',
#  'mqtli.a9r3.b1',
#  'drift_144',
#  'mqtli.a9r3.b1..2',
#  'drift_145',
#  'mqtli.b9r3.b1..1',
#  'drift_146',
#  'mqtli.b9r3.b1',
#  'drift_147',
#  'mqtli.b9r3.b1..2',
#  'drift_148',
#  'mcbch.9r3.b1',
#  'drift_149',
#  'mco.10r3.b1',
#  'drift_150',
#  'mcd.10r3.b1',
#  'drift_151',
#  'mb.a10r3.b1..1',
#  'drift_152',
#  'mb.a10r3.b1',
#  'drift_153',
#  'mb.a10r3.b1..2',
#  'drift_154',
#  'mcs.a10r3.b1',
#  'drift_155',
#  'mb.b10r3.b1..1',
#  'drift_156',
#  'mb.b10r3.b1',
#  'drift_157',
#  'mb.b10r3.b1..2',
#  'drift_158',
#  'mcs.b10r3.b1',
#  'drift_159',
#  'bpm.10r3.b1',
#  'drift_160',
#  'mq.10r3.b1..1',
#  'drift_161',
#  'mq.10r3.b1',
#  'drift_162',
#  'mq.10r3.b1..2',
#  'drift_163',
#  'mqtli.10r3.b1..1',
#  'drift_164',
#  'mqtli.10r3.b1',
#  'drift_165',
#  'mqtli.10r3.b1..2',
#  'drift_166',
#  'mcbcv.10r3.b1',
#  'drift_167',
#  'mco.11r3.b1',
#  'drift_168',
#  'mcd.11r3.b1',
#  'drift_169',
#  'mb.a11r3.b1..1',
#  'drift_170',
#  'mb.a11r3.b1',
#  'drift_171',
#  'mb.a11r3.b1..2',
#  'drift_172',
#  'mcs.a11r3.b1',
#  'drift_173',
#  'mb.b11r3.b1..1',
#  'drift_174',
#  'mb.b11r3.b1',
#  'drift_175',
#  'mb.b11r3.b1..2',
#  'drift_176',
#  'mcs.b11r3.b1',
#  'drift_177',
#  'leel.11r3.b1',
#  'drift_178',
#  'bpm.11r3.b1',
#  'drift_179',
#  'mq.11r3.b1..1',
#  'drift_180',
#  'mq.11r3.b1',
#  'drift_181',
#  'mq.11r3.b1..2',
#  'drift_182',
#  'mqtli.11r3.b1..1',
#  'drift_183',
#  'mqtli.11r3.b1',
#  'drift_184',
#  'mqtli.11r3.b1..2',
#  'drift_185',
#  'ms.11r3.b1',
#  'drift_186',
#  'mcbh.11r3.b1',
#  'drift_187',
#  's.arc.34.b1',
#  'drift_188',
#  'mco.a12r3.b1',
#  'drift_189',
#  'mcd.a12r3.b1',
#  'drift_190',
#  'mb.a12r3.b1..1',
#  'drift_191',
#  'mb.a12r3.b1',
#  'drift_192',
#  'mb.a12r3.b1..2',
#  'drift_193',
#  'mcs.a12r3.b1',
#  'drift_194',
#  'mb.b12r3.b1..1',
#  'drift_195',
#  'mb.b12r3.b1',
#  'drift_196',
#  'mb.b12r3.b1..2',
#  'drift_197',
#  'mcs.b12r3.b1',
#  'drift_198',
#  'mco.b12r3.b1',
#  'drift_199',
#  'mcd.b12r3.b1',
#  'drift_200',
#  'mb.c12r3.b1..1',
#  'drift_201',
#  'mb.c12r3.b1',
#  'drift_202',
#  'mb.c12r3.b1..2',
#  'drift_203',
#  'mcs.c12r3.b1',
#  'drift_204',
#  'bpm.12r3.b1',
#  'drift_205',
#  'mqt.12r3.b1..1',
#  'drift_206',
#  'mqt.12r3.b1',
#  'drift_207',
#  'mqt.12r3.b1..2',
#  'drift_208',
#  'mq.12r3.b1..1',
#  'drift_209',
#  'mq.12r3.b1',
#  'drift_210',
#  'mq.12r3.b1..2',
#  'drift_211',
#  'ms.12r3.b1',
#  'drift_212',
#  'mcbv.12r3.b1',
#  'drift_213',
#  'mb.a13r3.b1..1',
#  'drift_214',
#  'mb.a13r3.b1',
#  'drift_215',
#  'mb.a13r3.b1..2',
#  'drift_216',
#  'mcs.a13r3.b1',
#  'drift_217',
#  'mco.13r3.b1',
#  'drift_218',
#  'mcd.13r3.b1',
#  'drift_219',
#  'mb.b13r3.b1..1',
#  'drift_220',
#  'mb.b13r3.b1',
#  'drift_221',
#  'mb.b13r3.b1..2',
#  'drift_222',
#  'mcs.b13r3.b1',
#  'drift_223',
#  'mb.c13r3.b1..1',
#  'drift_224',
#  'mb.c13r3.b1',
#  'drift_225',
#  'mb.c13r3.b1..2',
#  'drift_226',
#  'mcs.c13r3.b1',
#  'drift_227',
#  'bpm.13r3.b1',
#  'drift_228',
#  'mqt.13r3.b1..1',
#  'drift_229',
#  'mqt.13r3.b1',
#  'drift_230',
#  'mqt.13r3.b1..2',
#  'drift_231',
#  'mq.13r3.b1..1',
#  'drift_232',
#  'mq.13r3.b1',
#  'drift_233',
#  'mq.13r3.b1..2',
#  'drift_234',
#  'ms.13r3.b1',
#  'drift_235',
#  'mcbh.13r3.b1',
#  'drift_236',
#  'e.ds.r3.b1',
#  'drift_237',
#  'mco.a14r3.b1',
#  'drift_238',
#  'mcd.a14r3.b1',
#  'drift_239',
#  'mb.a14r3.b1..1',
#  'drift_240',
#  'mb.a14r3.b1',
#  'drift_241',
#  'mb.a14r3.b1..2',
#  'drift_242',
#  'mcs.a14r3.b1',
#  'drift_243',
#  'mb.b14r3.b1..1',
#  'drift_244',
#  'mb.b14r3.b1',
#  'drift_245',
#  'mb.b14r3.b1..2',
#  'drift_246',
#  'mcs.b14r3.b1',
#  'drift_247',
#  'mco.b14r3.b1',
#  'drift_248',
#  'mcd.b14r3.b1',
#  'drift_249',
#  'mb.c14r3.b1..1',
#  'drift_250',
#  'mb.c14r3.b1',
#  'drift_251',
#  'mb.c14r3.b1..2',
#  'drift_252',
#  'mcs.c14r3.b1',
#  'drift_253',
#  'bpm.14r3.b1',
#  'drift_254',
#  'mqt.14r3.b1..1',
#  'drift_255',
#  'mqt.14r3.b1',
#  'drift_256',
#  'mqt.14r3.b1..2',
#  'drift_257',
#  'mq.14r3.b1..1',
#  'drift_258',
#  'mq.14r3.b1',
#  'drift_259',
#  'mq.14r3.b1..2',
#  'drift_260',
#  'ms.14r3.b1',
#  'drift_261',
#  'mcbv.14r3.b1',
#  'drift_262',
#  'mb.a15r3.b1..1',
#  'drift_263',
#  'mb.a15r3.b1',
#  'drift_264',
#  'mb.a15r3.b1..2',
#  'drift_265',
#  'mcs.a15r3.b1',
#  'drift_266',
#  'mco.15r3.b1',
#  'drift_267',
#  'mcd.15r3.b1',
#  'drift_268',
#  'mb.b15r3.b1..1',
#  'drift_269',
#  'mb.b15r3.b1',
#  'drift_270',
#  'mb.b15r3.b1..2',
#  'drift_271',
#  'mcs.b15r3.b1',
#  'drift_272',
#  'mb.c15r3.b1..1',
#  'drift_273',
#  'mb.c15r3.b1',
#  'drift_274',
#  'mb.c15r3.b1..2',
#  'drift_275',
#  'mcs.c15r3.b1',
#  'drift_276',
#  'bpm.15r3.b1',
#  'drift_277',
#  'mqt.15r3.b1..1',
#  'drift_278',
#  'mqt.15r3.b1',
#  'drift_279',
#  'mqt.15r3.b1..2',
#  'drift_280',
#  'mq.15r3.b1..1',
#  'drift_281',
#  'mq.15r3.b1',
#  'drift_282',
#  'mq.15r3.b1..2',
#  'drift_283',
#  'ms.15r3.b1',
#  'drift_284',
#  'mcbh.15r3.b1',
#  'drift_285',
#  'mco.a16r3.b1',
#  'drift_286',
#  'mcd.a16r3.b1',
#  'drift_287',
#  'mb.a16r3.b1..1',
#  'drift_288',
#  'mb.a16r3.b1',
#  'drift_289',
#  'mb.a16r3.b1..2',
#  'drift_290',
#  'mcs.a16r3.b1',
#  'drift_291',
#  'mb.b16r3.b1..1',
#  'drift_292',
#  'mb.b16r3.b1',
#  'drift_293',
#  'mb.b16r3.b1..2',
#  'drift_294',
#  'mcs.b16r3.b1',
#  'drift_295',
#  'mco.b16r3.b1',
#  'drift_296',
#  'mcd.b16r3.b1',
#  'drift_297',
#  'mb.c16r3.b1..1',
#  'drift_298',
#  'mb.c16r3.b1',
#  'drift_299',
#  'mb.c16r3.b1..2',
#  'drift_300',
#  'mcs.c16r3.b1',
#  'drift_301',
#  'bpm.16r3.b1',
#  'drift_302',
#  'mqt.16r3.b1..1',
#  'drift_303',
#  'mqt.16r3.b1',
#  'drift_304',
#  'mqt.16r3.b1..2',
#  'drift_305',
#  'mq.16r3.b1..1',
#  'drift_306',
#  'mq.16r3.b1',
#  'drift_307',
#  'mq.16r3.b1..2',
#  'drift_308',
#  'ms.16r3.b1',
#  'drift_309',
#  'mcbv.16r3.b1',
#  'drift_310',
#  'mb.a17r3.b1..1',
#  'drift_311',
#  'mb.a17r3.b1',
#  'drift_312',
#  'mb.a17r3.b1..2',
#  'drift_313',
#  'mcs.a17r3.b1',
#  'drift_314',
#  'mco.17r3.b1',
#  'drift_315',
#  'mcd.17r3.b1',
#  'drift_316',
#  'mb.b17r3.b1..1',
#  'drift_317',
#  'mb.b17r3.b1',
#  'drift_318',
#  'mb.b17r3.b1..2',
#  'drift_319',
#  'mcs.b17r3.b1',
#  'drift_320',
#  'mb.c17r3.b1..1',
#  'drift_321',
#  'mb.c17r3.b1',
#  'drift_322',
#  'mb.c17r3.b1..2',
#  'drift_323',
#  'mcs.c17r3.b1',
#  'drift_324',
#  'bpm.17r3.b1',
#  'drift_325',
#  'mqt.17r3.b1..1',
#  'drift_326',
#  'mqt.17r3.b1',
#  'drift_327',
#  'mqt.17r3.b1..2',
#  'drift_328',
#  'mq.17r3.b1..1',
#  'drift_329',
#  'mq.17r3.b1',
#  'drift_330',
#  'mq.17r3.b1..2',
#  'drift_331',
#  'ms.17r3.b1',
#  'drift_332',
#  'mcbh.17r3.b1',
#  'drift_333',
#  'mco.a18r3.b1',
#  'drift_334',
#  'mcd.a18r3.b1',
#  'drift_335',
#  'mb.a18r3.b1..1',
#  'drift_336',
#  'mb.a18r3.b1',
#  'drift_337',
#  'mb.a18r3.b1..2',
#  'drift_338',
#  'mcs.a18r3.b1',
#  'drift_339',
#  'mb.b18r3.b1..1',
#  'drift_340',
#  'mb.b18r3.b1',
#  'drift_341',
#  'mb.b18r3.b1..2',
#  'drift_342',
#  'mcs.b18r3.b1',
#  'drift_343',
#  'mco.b18r3.b1',
#  'drift_344',
#  'mcd.b18r3.b1',
#  'drift_345',
#  'mb.c18r3.b1..1',
#  'drift_346',
#  'mb.c18r3.b1',
#  'drift_347',
#  'mb.c18r3.b1..2',
#  'drift_348',
#  'mcs.c18r3.b1',
#  'drift_349',
#  'bpm.18r3.b1',
#  'drift_350',
#  'mqt.18r3.b1..1',
#  'drift_351',
#  'mqt.18r3.b1',
#  'drift_352',
#  'mqt.18r3.b1..2',
#  'drift_353',
#  'mq.18r3.b1..1',
#  'drift_354',
#  'mq.18r3.b1',
#  'drift_355',
#  'mq.18r3.b1..2',
#  'drift_356',
#  'ms.18r3.b1',
#  'drift_357',
#  'mcbv.18r3.b1',
#  'drift_358',
#  'mb.a19r3.b1..1',
#  'drift_359',
#  'mb.a19r3.b1',
#  'drift_360',
#  'mb.a19r3.b1..2',
#  'drift_361',
#  'mcs.a19r3.b1',
#  'drift_362',
#  'mco.19r3.b1',
#  'drift_363',
#  'mcd.19r3.b1',
#  'drift_364',
#  'mb.b19r3.b1..1',
#  'drift_365',
#  'mb.b19r3.b1',
#  'drift_366',
#  'mb.b19r3.b1..2',
#  'drift_367',
#  'mcs.b19r3.b1',
#  'drift_368',
#  'mb.c19r3.b1..1',
#  'drift_369',
#  'mb.c19r3.b1',
#  'drift_370',
#  'mb.c19r3.b1..2',
#  'drift_371',
#  'mcs.c19r3.b1',
#  'drift_372',
#  'bpm.19r3.b1',
#  'drift_373',
#  'mqt.19r3.b1..1',
#  'drift_374',
#  'mqt.19r3.b1',
#  'drift_375',
#  'mqt.19r3.b1..2',
#  'drift_376',
#  'mq.19r3.b1..1',
#  'drift_377',
#  'mq.19r3.b1',
#  'drift_378',
#  'mq.19r3.b1..2',
#  'drift_379',
#  'ms.19r3.b1',
#  'drift_380',
#  'mcbh.19r3.b1',
#  'drift_381',
#  'mco.a20r3.b1',
#  'drift_382',
#  'mcd.a20r3.b1',
#  'drift_383',
#  'mb.a20r3.b1..1',
#  'drift_384',
#  'mb.a20r3.b1',
#  'drift_385',
#  'mb.a20r3.b1..2',
#  'drift_386',
#  'mcs.a20r3.b1',
#  'drift_387',
#  'mb.b20r3.b1..1',
#  'drift_388',
#  'mb.b20r3.b1',
#  'drift_389',
#  'mb.b20r3.b1..2',
#  'drift_390',
#  'mcs.b20r3.b1',
#  'drift_391',
#  'mco.b20r3.b1',
#  'drift_392',
#  'mcd.b20r3.b1',
#  'drift_393',
#  'mb.c20r3.b1..1',
#  'drift_394',
#  'mb.c20r3.b1',
#  'drift_395',
#  'mb.c20r3.b1..2',
#  'drift_396',
#  'mcs.c20r3.b1',
#  'drift_397',
#  'bpm.20r3.b1',
#  'drift_398',
#  'mqt.20r3.b1..1',
#  'drift_399',
#  'mqt.20r3.b1',
#  'drift_400',
#  'mqt.20r3.b1..2',
#  'drift_401',
#  'mq.20r3.b1..1',
#  'drift_402',
#  'mq.20r3.b1',
#  'drift_403',
#  'mq.20r3.b1..2',
#  'drift_404',
#  'ms.20r3.b1',
#  'drift_405',
#  'mcbv.20r3.b1',
#  'drift_406',
#  'mb.a21r3.b1..1',
#  'drift_407',
#  'mb.a21r3.b1',
#  'drift_408',
#  'mb.a21r3.b1..2',
#  'drift_409',
#  'mcs.a21r3.b1',
#  'drift_410',
#  'mco.21r3.b1',
#  'drift_411',
#  'mcd.21r3.b1',
#  'drift_412',
#  'mb.b21r3.b1..1',
#  'drift_413',
#  'mb.b21r3.b1',
#  'drift_414',
#  'mb.b21r3.b1..2',
#  'drift_415',
#  'mcs.b21r3.b1',
#  'drift_416',
#  'mb.c21r3.b1..1',
#  'drift_417',
#  'mb.c21r3.b1',
#  'drift_418',
#  'mb.c21r3.b1..2',
#  'drift_419',
#  'mcs.c21r3.b1',
#  'drift_420',
#  'bpm.21r3.b1',
#  'drift_421',
#  'mqt.21r3.b1..1',
#  'drift_422',
#  'mqt.21r3.b1',
#  'drift_423',
#  'mqt.21r3.b1..2',
#  'drift_424',
#  'mq.21r3.b1..1',
#  'drift_425',
#  'mq.21r3.b1',
#  'drift_426',
#  'mq.21r3.b1..2',
#  'drift_427',
#  'ms.21r3.b1',
#  'drift_428',
#  'mcbh.21r3.b1',
#  'drift_429',
#  'mco.a22r3.b1',
#  'drift_430',
#  'mcd.a22r3.b1',
#  'drift_431',
#  'mb.a22r3.b1..1',
#  'drift_432',
#  'mb.a22r3.b1',
#  'drift_433',
#  'mb.a22r3.b1..2',
#  'drift_434',
#  'mcs.a22r3.b1',
#  'drift_435',
#  'mb.b22r3.b1..1',
#  'drift_436',
#  'mb.b22r3.b1',
#  'drift_437',
#  'mb.b22r3.b1..2',
#  'drift_438',
#  'mcs.b22r3.b1',
#  'drift_439',
#  'mco.b22r3.b1',
#  'drift_440',
#  'mcd.b22r3.b1',
#  'drift_441',
#  'mb.c22r3.b1..1',
#  'drift_442',
#  'mb.c22r3.b1',
#  'drift_443',
#  'mb.c22r3.b1..2',
#  'drift_444',
#  'mcs.c22r3.b1',
#  'drift_445',
#  'bpm.22r3.b1',
#  'drift_446',
#  'mo.22r3.b1',
#  'drift_447',
#  'mq.22r3.b1..1',
#  'drift_448',
#  'mq.22r3.b1',
#  'drift_449',
#  'mq.22r3.b1..2',
#  'drift_450',
#  'ms.22r3.b1',
#  'drift_451',
#  'mcbv.22r3.b1',
#  'drift_452',
#  'mb.a23r3.b1..1',
#  'drift_453',
#  'mb.a23r3.b1',
#  'drift_454',
#  'mb.a23r3.b1..2',
#  'drift_455',
#  'mcs.a23r3.b1',
#  'drift_456',
#  'mco.23r3.b1',
#  'drift_457',
#  'mcd.23r3.b1',
#  'drift_458',
#  'mb.b23r3.b1..1',
#  'drift_459',
#  'mb.b23r3.b1',
#  'drift_460',
#  'mb.b23r3.b1..2',
#  'drift_461',
#  'mcs.b23r3.b1',
#  'drift_462',
#  'mb.c23r3.b1..1',
#  'drift_463',
#  'mb.c23r3.b1',
#  'drift_464',
#  'mb.c23r3.b1..2',
#  'drift_465',
#  'mcs.c23r3.b1',
#  'drift_466',
#  'bpm.23r3.b1',
#  'drift_467',
#  'mqs.23r3.b1',
#  'drift_468',
#  'mq.23r3.b1..1',
#  'drift_469',
#  'mq.23r3.b1',
#  'drift_470',
#  'mq.23r3.b1..2',
#  'drift_471',
#  'ms.23r3.b1',
#  'drift_472',
#  'mcbh.23r3.b1',
#  'drift_473',
#  'mco.a24r3.b1',
#  'drift_474',
#  'mcd.a24r3.b1',
#  'drift_475',
#  'mb.a24r3.b1..1',
#  'drift_476',
#  'mb.a24r3.b1',
#  'drift_477',
#  'mb.a24r3.b1..2',
#  'drift_478',
#  'mcs.a24r3.b1',
#  'drift_479',
#  'mb.b24r3.b1..1',
#  'drift_480',
#  'mb.b24r3.b1',
#  'drift_481',
#  'mb.b24r3.b1..2',
#  'drift_482',
#  'mcs.b24r3.b1',
#  'drift_483',
#  'mco.b24r3.b1',
#  'drift_484',
#  'mcd.b24r3.b1',
#  'drift_485',
#  'mb.c24r3.b1..1',
#  'drift_486',
#  'mb.c24r3.b1',
#  'drift_487',
#  'mb.c24r3.b1..2',
#  'drift_488',
#  'mcs.c24r3.b1',
#  'drift_489',
#  'bpm.24r3.b1',
#  'drift_490',
#  'mo.24r3.b1',
#  'drift_491',
#  'mq.24r3.b1..1',
#  'drift_492',
#  'mq.24r3.b1',
#  'drift_493',
#  'mq.24r3.b1..2',
#  'drift_494',
#  'ms.24r3.b1',
#  'drift_495',
#  'mcbv.24r3.b1',
#  'drift_496',
#  'mb.a25r3.b1..1',
#  'drift_497',
#  'mb.a25r3.b1',
#  'drift_498',
#  'mb.a25r3.b1..2',
#  'drift_499',
#  ...)

# %%
collider.lhcb2.elements  # Element objects
# Out:
# (<xtrack.beam_elements.elements.Marker at 0x7feb9fd21b70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd21b10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd226b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd22710>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd22800>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd229b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd22a70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd22ad0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd225c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd21990>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd22ce0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd22e90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd22f50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd22fb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd230d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd230a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd23310>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd232e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd23550>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd23520>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd23790>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd23910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd239d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd23a30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd23b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd23b20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd23d90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd23d60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd23fa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd24040>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd24250>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd243d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd24490>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd244f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd24610>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd245e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd24850>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd24820>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd24a90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd24a60>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd24cd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd24e50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd24f10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd24f70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd25090>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd25060>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd252d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd252a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd25510>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd254e0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd25750>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd258d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd25990>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd259f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd25b10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd25ae0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd25d50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd25ed0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd25f90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd25ff0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd26110>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd260e0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd26350>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd264d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd26590>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd265f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd26710>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd266e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26950>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26ad0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26b90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26c50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26d10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26dd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26e90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd26f50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd27010>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd270d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd27190>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd271f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd27310>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd27490>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd27550>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd275b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd276d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd276a0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd27910>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd27a90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd27b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd27bb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd27cd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd27ca0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd27f10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd27ee0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd34190>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd34160>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd343d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd34550>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd34610>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd34670>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd34790>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd347c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd349a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd349d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd34a90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd34970>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd34e50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd34e20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35030>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35090>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35180>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35240>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35300>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd353c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35480>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35540>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd35600>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd353f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd357b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35810>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35900>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd359c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35a80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35b40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35c00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35cc0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd35d80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35b70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd35f30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd35f90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd36080>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36140>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd36200>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd362c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd36380>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36440>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd36500>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd362f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd366b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36710>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd367d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36800>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36920>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd365f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd36b00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36b60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd36c50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36d10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd36dd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36e90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36f50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd36d40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd37100>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37160>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd37250>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd373d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37490>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37550>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd37700>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37760>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd37850>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd374c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd37a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37a60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd37b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37c10>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd37cd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd37e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd37ee0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd37fd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38160>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd38190>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd382e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd38340>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd383a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd38490>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38550>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd38610>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd387c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38820>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd38910>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd389d0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd38a90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38700>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd38c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38ca0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd38d90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38e50>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd38f10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd38b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd390c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39120>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd39210>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd392d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39390>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39000>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39540>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39600>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39840>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39900>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd399c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39a20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd396f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39690>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd39ae0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39cc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd39d20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39d80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd39e70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39f30>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd39ff0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39c30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3a1a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3a200>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3a2f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39f60>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd3a4a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3a560>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3a620>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3a680>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3a770>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3a830>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd3a8f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3a3e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3aaa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3ab00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3abf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3acb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3ad70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3ae30>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd3aef0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3ace0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3b0a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3b1c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b1f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3b310>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3b4c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3b640>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b700>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd3b7c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b5b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3b970>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b9d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3bac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3bb80>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd3bc40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3b8b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd3bdf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3be50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd3bf70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd440d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd44130>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd44280>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44340>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd44400>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44070>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd445b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd44700>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd447c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd44880>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44940>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd44a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd447f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd44bb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44c10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd44d00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44dc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd44e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd44f40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd45000>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd450c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd45180>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45240>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd45300>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd450f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd454b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45510>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd45600>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd456c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd45780>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd453f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd45930>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45990>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd45a80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45b40>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd45c00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45870>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd45db0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45e10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45f00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd45b70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd460b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd46140>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd46380>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd462f0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd46590>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd46710>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd467d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd34520>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd348b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd46830>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd466e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd46230>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd469e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd466b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd46b60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd46bc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd46cb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd46d70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd46e30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd46ef0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd46fb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd47070>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd47130>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd471f0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd472b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd470a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd47460>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd474c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd475b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd47670>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd47730>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd473a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd478e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd47940>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd47a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd476a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd47be0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd47c40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd228c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd47d00>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd47e50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd47d90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd500a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd501f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd502b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd50370>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50430>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd50490>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd50670>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd506d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd507c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd50940>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd508b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd50c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50cd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd50dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50e80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd50f40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51000>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd510c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd50eb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd51270>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd512d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd513c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51480>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd51540>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd511b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd516f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51750>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51840>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd514b0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd519f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51ab0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd51b70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51bd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd51cc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51d80>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd51e40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd51930>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd51ff0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52050>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd52140>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52200>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd522c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52380>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd52440>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52230>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd525f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52650>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd52740>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52800>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd528c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52980>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd52a40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52b00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd52bc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52bf0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd52f20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52c80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd52ef0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd52d40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd530a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53160>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd53220>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd532e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd533a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53460>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd53520>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53310>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd536d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53730>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd53820>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd538e0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd539a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd53b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53bb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53ca0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd53e50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd53eb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd53fd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd580a0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd58160>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd582b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd58310>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd58460>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58520>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd585e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd586a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd58760>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58820>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd588e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd589a0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd58a60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58850>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd58c10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58c70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd58d60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58e20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd58ee0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58fa0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd59060>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd58e50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd59210>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59270>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd59360>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59420>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd594e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd595a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd59660>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59720>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd597e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd598a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd59990>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59900>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd599c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd598d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd59c30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59c90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd59d80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59e40>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd59f00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59b70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5a0b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5a110>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5a200>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd59e70>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd5a3b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5a470>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5a530>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5a590>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5a680>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5a740>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd5a800>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5a2f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5a9b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5aa10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5ab00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5abc0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5ac80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5ad40>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd5ae00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5abf0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5afb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5b010>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5b100>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5b1c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5b280>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5b340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5b400>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5b4c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5b580>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5b640>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd5b700>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5b4f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5ba30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5ba90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5bbb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd39480>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5bb80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5be50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd5b880>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5b910>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd5b970>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5bfd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd600a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd601f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd602b0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd60370>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd604c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd60520>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60580>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60670>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd602e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd60820>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd60970>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60a30>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd60af0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60760>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd60ca0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60d00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd60df0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd60eb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd60f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd61030>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd610f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd611b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd61270>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd61330>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd613f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd611e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd615a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd61600>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd616f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd617b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd61870>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd61930>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd619f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd617e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd61ba0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd61c00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd61cf0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd61db0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd61e70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd61f30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd61ff0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd620b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd62170>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62230>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd620e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd622f0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd62410>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62260>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd625f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62650>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd62740>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62800>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd628c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62530>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd62a70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62ad0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62bc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62830>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd62d70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62dd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd62ec0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62f80>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd63040>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd62cb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd631f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63250>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd63340>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd634c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63580>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd63640>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63430>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd637f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63850>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd63940>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63a00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd63ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd63c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63d00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd63dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd63e80>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd63f70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6c0d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6c130>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6c190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6c280>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6c2b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6c5b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6c580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6c7f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd5bca0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd52fe0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6c9a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6c340>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6c460>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6c3a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6ca30>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6cbb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6c910>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6cd60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6cdc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6ceb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6ca60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6d060>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6d0c0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6d1b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6d270>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6d330>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6cfa0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6d4e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6d540>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6d630>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6d6f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6d7b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6d870>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6d930>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6d9f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6dab0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6db70>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6dc30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6da20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6dde0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6de40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6df30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6dff0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6e0b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6e170>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6e230>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6e020>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6e3e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6e440>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6e530>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6e5f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6e6b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6e770>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6e830>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6e8f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6e9b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6ea70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6eb30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6ebf0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6ecb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6eaa0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6ee60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6eec0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6efb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6f070>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6f130>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6eda0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6f2e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6f340>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6f400>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6f580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6f5b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6f610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6f700>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6f7c0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6f880>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6f520>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6fa30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6fa90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6fb80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6fc40>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd6fd00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6fdc0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd6fe80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd6fc70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74070>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd740d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd741c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74340>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd744c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74580>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74640>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74700>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd747c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd745b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74970>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd749d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74ac0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74b80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74c40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74d00>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74df0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd74e80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd74d30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd74ee0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75180>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd75270>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75330>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd753f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75540>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd755a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75600>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd756f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75360>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd758a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75900>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd759f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75ab0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd75b70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd757e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd75d20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75d80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd75e70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd75f30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd75ff0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd760b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd76170>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76230>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd762f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd763b0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd76470>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76260>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd76620>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76680>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd76770>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76830>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd768f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd769b0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd76a70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76860>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd76c20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76c80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd76d70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76e30>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd76ef0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd76fb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd77070>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd77130>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd771f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd772b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd77370>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd77430>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd774f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd772e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd776a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd77700>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd777f0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd778b0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd77970>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd775e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd77b20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd77b80>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd77c70>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd778e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd77e20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd77e80>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd77fa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd77f40>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd80130>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80280>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd802e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80340>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd80430>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd804f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd805b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80670>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd80730>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80520>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd808e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80940>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd80a30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80af0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd80bb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80c70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd80d30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80df0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd80eb0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80f70>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd81030>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd80e20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd811e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd81240>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd81330>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd813f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd814b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd81570>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd81630>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd816f0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd817b0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd815a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd81960>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd819f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd81c60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fe770a0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd81e10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd81ea0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd81ae0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd81b40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd81f30>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd820b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd82110>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82170>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd82260>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82320>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd823e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82050>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd82590>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd825f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd826e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd827a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd82860>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82920>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd829e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82aa0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd82b60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82c20>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd82ce0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82ad0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd82e90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd82ef0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd82fe0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd830a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd83160>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd83220>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd832e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd830d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd83490>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd834f0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd835e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd836a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd83760>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd83820>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd838e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd839a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd83a60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd83b20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd83be0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd83ca0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fd83d60>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd83b50>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fd83f10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fd83f70>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb90070>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90160>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb90220>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90370>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb903d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90430>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90520>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90190>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb906d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90730>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb90820>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb908e0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb909a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb90b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90bb0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb90ca0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90d60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb90e20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90ee0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb90fa0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb90d90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb91150>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb911b0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb912a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91360>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb91420>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb914e0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb915a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91660>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb91720>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb917e0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb918a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91690>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb91a50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91ab0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb91ba0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91c60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb91d20>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91de0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb91ea0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91f60>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb92020>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb91e10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb921d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92230>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb92320>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb923e0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb924a0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92110>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb927d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92830>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb92560>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92620>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb92710>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92aa0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb92b00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92b60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb92c50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92d10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb92dd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb92e90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb92f50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93010>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb930d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93190>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb93250>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93040>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb93400>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93460>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb93550>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93610>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb936d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93790>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb93850>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93640>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb93a00>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93a60>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb93b50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93c10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb93cd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93d90>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb93e50>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb93f10>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb93fd0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98160>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb98190>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98250>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb98310>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98100>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb984c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98520>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb98610>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb986d0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98790>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98400>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb98940>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb989a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb98a90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98b50>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb98c10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98880>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb98dc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98e20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb98f10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb98fd0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99090>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99150>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb99210>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99000>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb993c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99420>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99510>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb995d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99690>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99750>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99810>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb998d0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99990>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99a50>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb99b10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99900>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99cc0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99d20>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99e10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb99ed0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb99f90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a050>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb9a110>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a1d0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb9a290>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a080>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb9a440>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a4a0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb9a590>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a650>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a710>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a380>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb9a8c0>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a920>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb9aa10>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9aad0>,
#  <xtrack.beam_elements.elements.Marker at 0x7feb9fb9ab90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9a800>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb9ad40>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9ada0>,
#  <xtrack.beam_elements.elements.Multipole at 0x7feb9fb9ae90>,
#  <xtrack.beam_elements.elements.Drift at 0x7feb9fb9af50>,
#  ...)

# %% [markdown]
# ### Access the properties of individual elements

# %%
collider.lhcb1['ip1']  # A marker element at one of the collision points (ATLAS experiment)

# %%
collider.lhcb1['mb.b18l3.b1..1']  # A bending magnet

# %%
collider.lhcb1['mb.b18l3.b1..1'].to_dict()  # We can view its properties
# Out:
# {'__class__': 'Multipole',
#  'order': 0,
#  'inv_factorial_order': 1.0,
#  'length': 7.15,
#  'hxl': 0.002549994037004702,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'knl': array([0.00254999]),
#  'ksl': array([0.])}

# %%
# A quadrupole
collider.lhcb1['mqwa.a4l3.b1..2']
collider.lhcb1['mqwa.a4l3.b1..2'].to_dict()
# Out:
# {'__class__': 'Multipole',
#  'order': 1,
#  'inv_factorial_order': 1.0,
#  'length': 0.777,
#  'hxl': 0.0,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'knl': array([0.        , 0.00096448]),
#  'ksl': array([0., 0.])}

# %% [markdown]
# ### Twiss
#
# Compute orbit, optics and other quantities of interest.

# %%
# Compute the twiss for the first beamline
twb1 = collider.lhcb1.twiss()

# Compute the twiss for the second beamline, and reverse it to have the two in the same reference frame
twb2 = collider.lhcb2.twiss().reverse()

# %% [markdown]
# ### Measure the tune

# %%
num_turns = 500

p_co = twb1.particle_on_co.copy()

collider.lhcb1.track(p_co, num_turns=num_turns, turn_by_turn_monitor=True)
mon_co = collider.lhcb1.record_last_track

p1 = twb1.particle_on_co.copy()
p1.x += 0.1e-3
p1.y += 0.2e-3
collider.lhcb1.track(p1, num_turns=num_turns, turn_by_turn_monitor=True)
mon1 = collider.lhcb1.record_last_track

# %%
# Plot turn-by-turn data
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Turn-by-turn data')
spx.plot(mon_co.x.T)
spx.plot(mon1.x.T)
spy.plot(mon_co.y.T)
spy.plot(mon1.y.T)
spy.set_xlabel('Turn')
spx.set_ylabel('x [m]')
spy.set_ylabel('y [m]')
# Out:
# Text(0, 0.5, 'y [m]')

# %%
# Plot the transverse spectrum
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Transverse spectrum')
freq_axis = np.fft.rfftfreq(n=num_turns)
spx.plot(freq_axis, np.abs(np.fft.rfft(mon1.x[0, :])))
spy.plot(freq_axis, np.abs(np.fft.rfft(mon1.y[0, :])))

# %%
fig, (spbet, spco) = plt.subplots(nrows=2, ncols=1, sharex=True)
tw = twb1
spbet.plot(tw['s'], tw['betx'])
spbet.plot(tw['s'], tw['bety'])
spbet.set_ylim(bottom=0)
spco.plot(tw['s'], tw['x'], label='x')
spco.plot(tw['s'], tw['y'], label='y')
spco.legend()
spbet.set_ylabel(r'$\beta_{x,y}$ [m]')
spco.set_ylabel(r'(Closed orbit)$_{x,y}$ [m]')

# vertical lines at IPs with labels next to them at the top of the plot
for ip in ['ip1', 'ip2', 'ip5', 'ip8']:
    spbet.axvline(x=tw['s', ip], color='k', alpha=0.2, linestyle='--')
    spco.axvline(x=tw['s', ip], color='k', alpha=0.2, linestyle='--')


fig.suptitle(
    r'$q_x$ = ' f'{tw["qx"]:.5f}' r' $q_y$ = ' f'{tw["qy"]:.5f}' '\n'
    r"$Q'_x$ = " f'{tw["dqx"]:.2f}' r" $Q'_y$ = " f'{tw["dqy"]:.2f}'
    r' $\gamma_{tr}$ = '  f'{1/np.sqrt(tw["momentum_compaction_factor"]):.2f}'
)
# Out:
# Text(0.5, 0.98, "$q_x$ = 62.31001 $q_y$ = 60.32001\n$Q'_x$ = 2.04 $Q'_y$ = 3.06 $\\gamma_{tr}$ = 53.54")

# %% [markdown]
# ### Survey

# %%
# Run the survey
sv1 = collider.lhcb1.survey(element0='ip1')
sv2 = collider.lhcb2.survey(element0='ip1').reverse()

# %%
# Draw the plot
offset = 200.

twb1_ir1 = twb1.rows[twb1['s', 'ip1']-offset:twb1['s', 'ip1']+offset:'s']
svb1_ir1 = sv1.rows[sv1['s', 'ip1']-offset:sv1['s', 'ip1']+offset:'s']

twb2_ir1 = twb2.rows[twb2['s', 'ip1']-offset:twb2['s', 'ip1']+offset:'s']
svb2_ir1 = sv2.rows[sv2['s', 'ip1']-offset:sv2['s', 'ip1']+offset:'s']

fig, ax = plt.subplots()
fig.suptitle('IP1 (ATLAS experiment)')
ax.plot(svb1_ir1.Z, svb1_ir1.X, label='x', linestyle='--', color='b')
ax.plot(svb2_ir1.Z, svb2_ir1.X, label='y', linestyle='--', color='r')

ax.plot(svb1_ir1.Z, svb1_ir1.X + twb1_ir1.x, label='x', linestyle='-', color='b')
ax.plot(svb2_ir1.Z, svb2_ir1.X + twb2_ir1.x, label='y', linestyle='-', color='r')

# %%
# See the whole ring
fig, ax = plt.subplots()
fig.suptitle('LHC Ring')
ax.set_box_aspect(1)
ax.plot(sv1.Z, sv1.X, label='x', linestyle='--', color='b')
ax.plot(sv2.Z, sv2.X, label='y', linestyle='--', color='r')

ax.plot(sv1.Z, sv1.X + twb1.x, label='x', linestyle='-', color='b')
ax.plot(sv2.Z, sv2.X + twb2.x, label='y', linestyle='-', color='r')
