# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

import xpart as xp
import xtrack as xt

fname_model = './generate_models/lhc_at_collisions.json'

nemitt_x = 2.5e-6
nemitt_y = 2.5e-6

collider = xt.Multiline.from_json(fname_model)
collider.build_trackers()
# Out:
# /Users/giadarol/xsuite_packages/xtrack/xtrack/progress_indicator.py:95: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Loading line from dict:   0%|          | 0/23684 [00:00<?, ?it/s]
# Done loading line from dict.
# Loading line from dict:   0%|          | 0/23688 [00:00<?, ?it/s]
# Done loading line from dict.
# Loading line from dict:   0%|          | 0/23684 [00:00<?, ?it/s]
# Done loading line from dict.
# Loading line from dict:   0%|          | 0/23688 [00:00<?, ?it/s]
# Done loading line from dict.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.

# %% [markdown]
# ## Exploring the LHC
#
# The two beamlines are accessible through `collider.lhcb1` and `collider.lhcb2`. Some examples on how we can access the elements of the lines.
#
# ### Enumerate elements and their names

# %%
collider.lhcb1.element_names  # Element names
# Out:
# ('ip3',
#  'drift_0',
#  'mcbwv.4r3.b1',
#  'drift_1',
#  'bpmw.4r3.b1',
#  'drift_2',
#  'mqwa.a4r3.b1..1',
#  'drift_3',
#  'mqwa.a4r3.b1..2',
#  'drift_4',
#  'mqwa.a4r3.b1',
#  'drift_5',
#  'mqwa.a4r3.b1..3',
#  'drift_6',
#  'mqwa.a4r3.b1..4',
#  'drift_7',
#  'mqwa.b4r3.b1..1',
#  'drift_8',
#  'mqwa.b4r3.b1..2',
#  'drift_9',
#  'mqwa.b4r3.b1',
#  'drift_10',
#  'mqwa.b4r3.b1..3',
#  'drift_11',
#  'mqwa.b4r3.b1..4',
#  'drift_12',
#  'mqwb.4r3.b1..1',
#  'drift_13',
#  'mqwb.4r3.b1..2',
#  'drift_14',
#  'mqwb.4r3.b1',
#  'drift_15',
#  'mqwb.4r3.b1..3',
#  'drift_16',
#  'mqwb.4r3.b1..4',
#  'drift_17',
#  'mqwa.c4r3.b1..1',
#  'drift_18',
#  'mqwa.c4r3.b1..2',
#  'drift_19',
#  'mqwa.c4r3.b1',
#  'drift_20',
#  'mqwa.c4r3.b1..3',
#  'drift_21',
#  'mqwa.c4r3.b1..4',
#  'drift_22',
#  'mqwa.d4r3.b1..1',
#  'drift_23',
#  'mqwa.d4r3.b1..2',
#  'drift_24',
#  'mqwa.d4r3.b1',
#  'drift_25',
#  'mqwa.d4r3.b1..3',
#  'drift_26',
#  'mqwa.d4r3.b1..4',
#  'drift_27',
#  'tcsg.4r3.b1',
#  'drift_28',
#  'mqwa.e4r3.b1..1',
#  'drift_29',
#  'mqwa.e4r3.b1..2',
#  'drift_30',
#  'mqwa.e4r3.b1',
#  'drift_31',
#  'mqwa.e4r3.b1..3',
#  'drift_32',
#  'mqwa.e4r3.b1..4',
#  'drift_33',
#  'bpmwe.4r3.b1',
#  'drift_34',
#  'tcsg.a5r3.b1',
#  'drift_35',
#  'tcsg.b5r3.b1',
#  'drift_36',
#  'tcla.a5r3.b1',
#  'drift_37',
#  'tcla.b5r3.b1',
#  'drift_38',
#  'mcbwh.5r3.b1',
#  'drift_39',
#  'bpmw.5r3.b1',
#  'drift_40',
#  'mqwa.a5r3.b1..1',
#  'drift_41',
#  'mqwa.a5r3.b1..2',
#  'drift_42',
#  'mqwa.a5r3.b1',
#  'drift_43',
#  'mqwa.a5r3.b1..3',
#  'drift_44',
#  'mqwa.a5r3.b1..4',
#  'drift_45',
#  'mqwa.b5r3.b1..1',
#  'drift_46',
#  'mqwa.b5r3.b1..2',
#  'drift_47',
#  'mqwa.b5r3.b1',
#  'drift_48',
#  'mqwa.b5r3.b1..3',
#  'drift_49',
#  'mqwa.b5r3.b1..4',
#  'drift_50',
#  'mqwb.5r3.b1..1',
#  'drift_51',
#  'mqwb.5r3.b1..2',
#  'drift_52',
#  'mqwb.5r3.b1',
#  'drift_53',
#  'mqwb.5r3.b1..3',
#  'drift_54',
#  'mqwb.5r3.b1..4',
#  'drift_55',
#  'mqwa.c5r3.b1..1',
#  'drift_56',
#  'mqwa.c5r3.b1..2',
#  'drift_57',
#  'mqwa.c5r3.b1',
#  'drift_58',
#  'mqwa.c5r3.b1..3',
#  'drift_59',
#  'mqwa.c5r3.b1..4',
#  'drift_60',
#  'mqwa.d5r3.b1..1',
#  'drift_61',
#  'mqwa.d5r3.b1..2',
#  'drift_62',
#  'mqwa.d5r3.b1',
#  'drift_63',
#  'mqwa.d5r3.b1..3',
#  'drift_64',
#  'mqwa.d5r3.b1..4',
#  'drift_65',
#  'mqwa.e5r3.b1..1',
#  'drift_66',
#  'mqwa.e5r3.b1..2',
#  'drift_67',
#  'mqwa.e5r3.b1',
#  'drift_68',
#  'mqwa.e5r3.b1..3',
#  'drift_69',
#  'mqwa.e5r3.b1..4',
#  'drift_70',
#  'bpmwj.a5r3.b1',
#  'drift_71',
#  'mbw.a6r3.b1',
#  'drift_72',
#  'mbw.b6r3.b1',
#  'drift_73',
#  'mbw.c6r3.b1',
#  'drift_74',
#  'tcla.6r3.b1',
#  'drift_75',
#  'mbw.d6r3.b1',
#  'drift_76',
#  'mbw.e6r3.b1',
#  'drift_77',
#  'mbw.f6r3.b1',
#  'drift_78',
#  'bpmwc.6r3.b1',
#  'drift_79',
#  'mcbcv.6r3.b1',
#  'drift_80',
#  'mqtlh.a6r3.b1..1',
#  'drift_81',
#  'mqtlh.a6r3.b1',
#  'drift_82',
#  'mqtlh.a6r3.b1..2',
#  'drift_83',
#  'mqtlh.b6r3.b1..1',
#  'drift_84',
#  'mqtlh.b6r3.b1',
#  'drift_85',
#  'mqtlh.b6r3.b1..2',
#  'drift_86',
#  'mqtlh.c6r3.b1..1',
#  'drift_87',
#  'mqtlh.c6r3.b1',
#  'drift_88',
#  'mqtlh.c6r3.b1..2',
#  'drift_89',
#  'mqtlh.d6r3.b1..1',
#  'drift_90',
#  'mqtlh.d6r3.b1',
#  'drift_91',
#  'mqtlh.d6r3.b1..2',
#  'drift_92',
#  'mqtlh.e6r3.b1..1',
#  'drift_93',
#  'mqtlh.e6r3.b1',
#  'drift_94',
#  'mqtlh.e6r3.b1..2',
#  'drift_95',
#  'mqtlh.f6r3.b1..1',
#  'drift_96',
#  'mqtlh.f6r3.b1',
#  'drift_97',
#  'mqtlh.f6r3.b1..2',
#  'drift_98',
#  'bpmr.6r3.b1',
#  'drift_99',
#  'tcla.7r3.b1',
#  'drift_100',
#  'dfbaf.7r3.b1',
#  'drift_101',
#  'bpm_a.7r3.b1',
#  'drift_102',
#  'mq.7r3.b1..1',
#  'drift_103',
#  'mq.7r3.b1',
#  'drift_104',
#  'mq.7r3.b1..2',
#  'drift_105',
#  'mqtli.7r3.b1..1',
#  'drift_106',
#  'mqtli.7r3.b1',
#  'drift_107',
#  'mqtli.7r3.b1..2',
#  'drift_108',
#  'mcbch.7r3.b1',
#  'drift_109',
#  's.ds.r3.b1',
#  'drift_110',
#  'mco.8r3.b1',
#  'drift_111',
#  'mcd.8r3.b1',
#  'drift_112',
#  'mb.a8r3.b1..1',
#  'drift_113',
#  'mb.a8r3.b1',
#  'drift_114',
#  'mb.a8r3.b1..2',
#  'drift_115',
#  'mcs.a8r3.b1',
#  'drift_116',
#  'mb.b8r3.b1..1',
#  'drift_117',
#  'mb.b8r3.b1',
#  'drift_118',
#  'mb.b8r3.b1..2',
#  'drift_119',
#  'mcs.b8r3.b1',
#  'drift_120',
#  'bpm.8r3.b1',
#  'drift_121',
#  'mq.8r3.b1..1',
#  'drift_122',
#  'mq.8r3.b1',
#  'drift_123',
#  'mq.8r3.b1..2',
#  'drift_124',
#  'mqtli.8r3.b1..1',
#  'drift_125',
#  'mqtli.8r3.b1',
#  'drift_126',
#  'mqtli.8r3.b1..2',
#  'drift_127',
#  'mcbcv.8r3.b1',
#  'drift_128',
#  'mco.9r3.b1',
#  'drift_129',
#  'mcd.9r3.b1',
#  'drift_130',
#  'mb.a9r3.b1..1',
#  'drift_131',
#  'mb.a9r3.b1',
#  'drift_132',
#  'mb.a9r3.b1..2',
#  'drift_133',
#  'mcs.a9r3.b1',
#  'drift_134',
#  'mb.b9r3.b1..1',
#  'drift_135',
#  'mb.b9r3.b1',
#  'drift_136',
#  'mb.b9r3.b1..2',
#  'drift_137',
#  'mcs.b9r3.b1',
#  'drift_138',
#  'bpm.9r3.b1',
#  'drift_139',
#  'mq.9r3.b1..1',
#  'drift_140',
#  'mq.9r3.b1',
#  'drift_141',
#  'mq.9r3.b1..2',
#  'drift_142',
#  'mqtli.a9r3.b1..1',
#  'drift_143',
#  'mqtli.a9r3.b1',
#  'drift_144',
#  'mqtli.a9r3.b1..2',
#  'drift_145',
#  'mqtli.b9r3.b1..1',
#  'drift_146',
#  'mqtli.b9r3.b1',
#  'drift_147',
#  'mqtli.b9r3.b1..2',
#  'drift_148',
#  'mcbch.9r3.b1',
#  'drift_149',
#  'mco.10r3.b1',
#  'drift_150',
#  'mcd.10r3.b1',
#  'drift_151',
#  'mb.a10r3.b1..1',
#  'drift_152',
#  'mb.a10r3.b1',
#  'drift_153',
#  'mb.a10r3.b1..2',
#  'drift_154',
#  'mcs.a10r3.b1',
#  'drift_155',
#  'mb.b10r3.b1..1',
#  'drift_156',
#  'mb.b10r3.b1',
#  'drift_157',
#  'mb.b10r3.b1..2',
#  'drift_158',
#  'mcs.b10r3.b1',
#  'drift_159',
#  'bpm.10r3.b1',
#  'drift_160',
#  'mq.10r3.b1..1',
#  'drift_161',
#  'mq.10r3.b1',
#  'drift_162',
#  'mq.10r3.b1..2',
#  'drift_163',
#  'mqtli.10r3.b1..1',
#  'drift_164',
#  'mqtli.10r3.b1',
#  'drift_165',
#  'mqtli.10r3.b1..2',
#  'drift_166',
#  'mcbcv.10r3.b1',
#  'drift_167',
#  'mco.11r3.b1',
#  'drift_168',
#  'mcd.11r3.b1',
#  'drift_169',
#  'mb.a11r3.b1..1',
#  'drift_170',
#  'mb.a11r3.b1',
#  'drift_171',
#  'mb.a11r3.b1..2',
#  'drift_172',
#  'mcs.a11r3.b1',
#  'drift_173',
#  'mb.b11r3.b1..1',
#  'drift_174',
#  'mb.b11r3.b1',
#  'drift_175',
#  'mb.b11r3.b1..2',
#  'drift_176',
#  'mcs.b11r3.b1',
#  'drift_177',
#  'leel.11r3.b1',
#  'drift_178',
#  'bpm.11r3.b1',
#  'drift_179',
#  'mq.11r3.b1..1',
#  'drift_180',
#  'mq.11r3.b1',
#  'drift_181',
#  'mq.11r3.b1..2',
#  'drift_182',
#  'mqtli.11r3.b1..1',
#  'drift_183',
#  'mqtli.11r3.b1',
#  'drift_184',
#  'mqtli.11r3.b1..2',
#  'drift_185',
#  'ms.11r3.b1',
#  'drift_186',
#  'mcbh.11r3.b1',
#  'drift_187',
#  's.arc.34.b1',
#  'drift_188',
#  'mco.a12r3.b1',
#  'drift_189',
#  'mcd.a12r3.b1',
#  'drift_190',
#  'mb.a12r3.b1..1',
#  'drift_191',
#  'mb.a12r3.b1',
#  'drift_192',
#  'mb.a12r3.b1..2',
#  'drift_193',
#  'mcs.a12r3.b1',
#  'drift_194',
#  'mb.b12r3.b1..1',
#  'drift_195',
#  'mb.b12r3.b1',
#  'drift_196',
#  'mb.b12r3.b1..2',
#  'drift_197',
#  'mcs.b12r3.b1',
#  'drift_198',
#  'mco.b12r3.b1',
#  'drift_199',
#  'mcd.b12r3.b1',
#  'drift_200',
#  'mb.c12r3.b1..1',
#  'drift_201',
#  'mb.c12r3.b1',
#  'drift_202',
#  'mb.c12r3.b1..2',
#  'drift_203',
#  'mcs.c12r3.b1',
#  'drift_204',
#  'bpm.12r3.b1',
#  'drift_205',
#  'mqt.12r3.b1..1',
#  'drift_206',
#  'mqt.12r3.b1',
#  'drift_207',
#  'mqt.12r3.b1..2',
#  'drift_208',
#  'mq.12r3.b1..1',
#  'drift_209',
#  'mq.12r3.b1',
#  'drift_210',
#  'mq.12r3.b1..2',
#  'drift_211',
#  'ms.12r3.b1',
#  'drift_212',
#  'mcbv.12r3.b1',
#  'drift_213',
#  'mb.a13r3.b1..1',
#  'drift_214',
#  'mb.a13r3.b1',
#  'drift_215',
#  'mb.a13r3.b1..2',
#  'drift_216',
#  'mcs.a13r3.b1',
#  'drift_217',
#  'mco.13r3.b1',
#  'drift_218',
#  'mcd.13r3.b1',
#  'drift_219',
#  'mb.b13r3.b1..1',
#  'drift_220',
#  'mb.b13r3.b1',
#  'drift_221',
#  'mb.b13r3.b1..2',
#  'drift_222',
#  'mcs.b13r3.b1',
#  'drift_223',
#  'mb.c13r3.b1..1',
#  'drift_224',
#  'mb.c13r3.b1',
#  'drift_225',
#  'mb.c13r3.b1..2',
#  'drift_226',
#  'mcs.c13r3.b1',
#  'drift_227',
#  'bpm.13r3.b1',
#  'drift_228',
#  'mqt.13r3.b1..1',
#  'drift_229',
#  'mqt.13r3.b1',
#  'drift_230',
#  'mqt.13r3.b1..2',
#  'drift_231',
#  'mq.13r3.b1..1',
#  'drift_232',
#  'mq.13r3.b1',
#  'drift_233',
#  'mq.13r3.b1..2',
#  'drift_234',
#  'ms.13r3.b1',
#  'drift_235',
#  'mcbh.13r3.b1',
#  'drift_236',
#  'e.ds.r3.b1',
#  'drift_237',
#  'mco.a14r3.b1',
#  'drift_238',
#  'mcd.a14r3.b1',
#  'drift_239',
#  'mb.a14r3.b1..1',
#  'drift_240',
#  'mb.a14r3.b1',
#  'drift_241',
#  'mb.a14r3.b1..2',
#  'drift_242',
#  'mcs.a14r3.b1',
#  'drift_243',
#  'mb.b14r3.b1..1',
#  'drift_244',
#  'mb.b14r3.b1',
#  'drift_245',
#  'mb.b14r3.b1..2',
#  'drift_246',
#  'mcs.b14r3.b1',
#  'drift_247',
#  'mco.b14r3.b1',
#  'drift_248',
#  'mcd.b14r3.b1',
#  'drift_249',
#  'mb.c14r3.b1..1',
#  'drift_250',
#  'mb.c14r3.b1',
#  'drift_251',
#  'mb.c14r3.b1..2',
#  'drift_252',
#  'mcs.c14r3.b1',
#  'drift_253',
#  'bpm.14r3.b1',
#  'drift_254',
#  'mqt.14r3.b1..1',
#  'drift_255',
#  'mqt.14r3.b1',
#  'drift_256',
#  'mqt.14r3.b1..2',
#  'drift_257',
#  'mq.14r3.b1..1',
#  'drift_258',
#  'mq.14r3.b1',
#  'drift_259',
#  'mq.14r3.b1..2',
#  'drift_260',
#  'ms.14r3.b1',
#  'drift_261',
#  'mcbv.14r3.b1',
#  'drift_262',
#  'mb.a15r3.b1..1',
#  'drift_263',
#  'mb.a15r3.b1',
#  'drift_264',
#  'mb.a15r3.b1..2',
#  'drift_265',
#  'mcs.a15r3.b1',
#  'drift_266',
#  'mco.15r3.b1',
#  'drift_267',
#  'mcd.15r3.b1',
#  'drift_268',
#  'mb.b15r3.b1..1',
#  'drift_269',
#  'mb.b15r3.b1',
#  'drift_270',
#  'mb.b15r3.b1..2',
#  'drift_271',
#  'mcs.b15r3.b1',
#  'drift_272',
#  'mb.c15r3.b1..1',
#  'drift_273',
#  'mb.c15r3.b1',
#  'drift_274',
#  'mb.c15r3.b1..2',
#  'drift_275',
#  'mcs.c15r3.b1',
#  'drift_276',
#  'bpm.15r3.b1',
#  'drift_277',
#  'mqt.15r3.b1..1',
#  'drift_278',
#  'mqt.15r3.b1',
#  'drift_279',
#  'mqt.15r3.b1..2',
#  'drift_280',
#  'mq.15r3.b1..1',
#  'drift_281',
#  'mq.15r3.b1',
#  'drift_282',
#  'mq.15r3.b1..2',
#  'drift_283',
#  'ms.15r3.b1',
#  'drift_284',
#  'mcbh.15r3.b1',
#  'drift_285',
#  'mco.a16r3.b1',
#  'drift_286',
#  'mcd.a16r3.b1',
#  'drift_287',
#  'mb.a16r3.b1..1',
#  'drift_288',
#  'mb.a16r3.b1',
#  'drift_289',
#  'mb.a16r3.b1..2',
#  'drift_290',
#  'mcs.a16r3.b1',
#  'drift_291',
#  'mb.b16r3.b1..1',
#  'drift_292',
#  'mb.b16r3.b1',
#  'drift_293',
#  'mb.b16r3.b1..2',
#  'drift_294',
#  'mcs.b16r3.b1',
#  'drift_295',
#  'mco.b16r3.b1',
#  'drift_296',
#  'mcd.b16r3.b1',
#  'drift_297',
#  'mb.c16r3.b1..1',
#  'drift_298',
#  'mb.c16r3.b1',
#  'drift_299',
#  'mb.c16r3.b1..2',
#  'drift_300',
#  'mcs.c16r3.b1',
#  'drift_301',
#  'bpm.16r3.b1',
#  'drift_302',
#  'mqt.16r3.b1..1',
#  'drift_303',
#  'mqt.16r3.b1',
#  'drift_304',
#  'mqt.16r3.b1..2',
#  'drift_305',
#  'mq.16r3.b1..1',
#  'drift_306',
#  'mq.16r3.b1',
#  'drift_307',
#  'mq.16r3.b1..2',
#  'drift_308',
#  'ms.16r3.b1',
#  'drift_309',
#  'mcbv.16r3.b1',
#  'drift_310',
#  'mb.a17r3.b1..1',
#  'drift_311',
#  'mb.a17r3.b1',
#  'drift_312',
#  'mb.a17r3.b1..2',
#  'drift_313',
#  'mcs.a17r3.b1',
#  'drift_314',
#  'mco.17r3.b1',
#  'drift_315',
#  'mcd.17r3.b1',
#  'drift_316',
#  'mb.b17r3.b1..1',
#  'drift_317',
#  'mb.b17r3.b1',
#  'drift_318',
#  'mb.b17r3.b1..2',
#  'drift_319',
#  'mcs.b17r3.b1',
#  'drift_320',
#  'mb.c17r3.b1..1',
#  'drift_321',
#  'mb.c17r3.b1',
#  'drift_322',
#  'mb.c17r3.b1..2',
#  'drift_323',
#  'mcs.c17r3.b1',
#  'drift_324',
#  'bpm.17r3.b1',
#  'drift_325',
#  'mqt.17r3.b1..1',
#  'drift_326',
#  'mqt.17r3.b1',
#  'drift_327',
#  'mqt.17r3.b1..2',
#  'drift_328',
#  'mq.17r3.b1..1',
#  'drift_329',
#  'mq.17r3.b1',
#  'drift_330',
#  'mq.17r3.b1..2',
#  'drift_331',
#  'ms.17r3.b1',
#  'drift_332',
#  'mcbh.17r3.b1',
#  'drift_333',
#  'mco.a18r3.b1',
#  'drift_334',
#  'mcd.a18r3.b1',
#  'drift_335',
#  'mb.a18r3.b1..1',
#  'drift_336',
#  'mb.a18r3.b1',
#  'drift_337',
#  'mb.a18r3.b1..2',
#  'drift_338',
#  'mcs.a18r3.b1',
#  'drift_339',
#  'mb.b18r3.b1..1',
#  'drift_340',
#  'mb.b18r3.b1',
#  'drift_341',
#  'mb.b18r3.b1..2',
#  'drift_342',
#  'mcs.b18r3.b1',
#  'drift_343',
#  'mco.b18r3.b1',
#  'drift_344',
#  'mcd.b18r3.b1',
#  'drift_345',
#  'mb.c18r3.b1..1',
#  'drift_346',
#  'mb.c18r3.b1',
#  'drift_347',
#  'mb.c18r3.b1..2',
#  'drift_348',
#  'mcs.c18r3.b1',
#  'drift_349',
#  'bpm.18r3.b1',
#  'drift_350',
#  'mqt.18r3.b1..1',
#  'drift_351',
#  'mqt.18r3.b1',
#  'drift_352',
#  'mqt.18r3.b1..2',
#  'drift_353',
#  'mq.18r3.b1..1',
#  'drift_354',
#  'mq.18r3.b1',
#  'drift_355',
#  'mq.18r3.b1..2',
#  'drift_356',
#  'ms.18r3.b1',
#  'drift_357',
#  'mcbv.18r3.b1',
#  'drift_358',
#  'mb.a19r3.b1..1',
#  'drift_359',
#  'mb.a19r3.b1',
#  'drift_360',
#  'mb.a19r3.b1..2',
#  'drift_361',
#  'mcs.a19r3.b1',
#  'drift_362',
#  'mco.19r3.b1',
#  'drift_363',
#  'mcd.19r3.b1',
#  'drift_364',
#  'mb.b19r3.b1..1',
#  'drift_365',
#  'mb.b19r3.b1',
#  'drift_366',
#  'mb.b19r3.b1..2',
#  'drift_367',
#  'mcs.b19r3.b1',
#  'drift_368',
#  'mb.c19r3.b1..1',
#  'drift_369',
#  'mb.c19r3.b1',
#  'drift_370',
#  'mb.c19r3.b1..2',
#  'drift_371',
#  'mcs.c19r3.b1',
#  'drift_372',
#  'bpm.19r3.b1',
#  'drift_373',
#  'mqt.19r3.b1..1',
#  'drift_374',
#  'mqt.19r3.b1',
#  'drift_375',
#  'mqt.19r3.b1..2',
#  'drift_376',
#  'mq.19r3.b1..1',
#  'drift_377',
#  'mq.19r3.b1',
#  'drift_378',
#  'mq.19r3.b1..2',
#  'drift_379',
#  'ms.19r3.b1',
#  'drift_380',
#  'mcbh.19r3.b1',
#  'drift_381',
#  'mco.a20r3.b1',
#  'drift_382',
#  'mcd.a20r3.b1',
#  'drift_383',
#  'mb.a20r3.b1..1',
#  'drift_384',
#  'mb.a20r3.b1',
#  'drift_385',
#  'mb.a20r3.b1..2',
#  'drift_386',
#  'mcs.a20r3.b1',
#  'drift_387',
#  'mb.b20r3.b1..1',
#  'drift_388',
#  'mb.b20r3.b1',
#  'drift_389',
#  'mb.b20r3.b1..2',
#  'drift_390',
#  'mcs.b20r3.b1',
#  'drift_391',
#  'mco.b20r3.b1',
#  'drift_392',
#  'mcd.b20r3.b1',
#  'drift_393',
#  'mb.c20r3.b1..1',
#  'drift_394',
#  'mb.c20r3.b1',
#  'drift_395',
#  'mb.c20r3.b1..2',
#  'drift_396',
#  'mcs.c20r3.b1',
#  'drift_397',
#  'bpm.20r3.b1',
#  'drift_398',
#  'mqt.20r3.b1..1',
#  'drift_399',
#  'mqt.20r3.b1',
#  'drift_400',
#  'mqt.20r3.b1..2',
#  'drift_401',
#  'mq.20r3.b1..1',
#  'drift_402',
#  'mq.20r3.b1',
#  'drift_403',
#  'mq.20r3.b1..2',
#  'drift_404',
#  'ms.20r3.b1',
#  'drift_405',
#  'mcbv.20r3.b1',
#  'drift_406',
#  'mb.a21r3.b1..1',
#  'drift_407',
#  'mb.a21r3.b1',
#  'drift_408',
#  'mb.a21r3.b1..2',
#  'drift_409',
#  'mcs.a21r3.b1',
#  'drift_410',
#  'mco.21r3.b1',
#  'drift_411',
#  'mcd.21r3.b1',
#  'drift_412',
#  'mb.b21r3.b1..1',
#  'drift_413',
#  'mb.b21r3.b1',
#  'drift_414',
#  'mb.b21r3.b1..2',
#  'drift_415',
#  'mcs.b21r3.b1',
#  'drift_416',
#  'mb.c21r3.b1..1',
#  'drift_417',
#  'mb.c21r3.b1',
#  'drift_418',
#  'mb.c21r3.b1..2',
#  'drift_419',
#  'mcs.c21r3.b1',
#  'drift_420',
#  'bpm.21r3.b1',
#  'drift_421',
#  'mqt.21r3.b1..1',
#  'drift_422',
#  'mqt.21r3.b1',
#  'drift_423',
#  'mqt.21r3.b1..2',
#  'drift_424',
#  'mq.21r3.b1..1',
#  'drift_425',
#  'mq.21r3.b1',
#  'drift_426',
#  'mq.21r3.b1..2',
#  'drift_427',
#  'ms.21r3.b1',
#  'drift_428',
#  'mcbh.21r3.b1',
#  'drift_429',
#  'mco.a22r3.b1',
#  'drift_430',
#  'mcd.a22r3.b1',
#  'drift_431',
#  'mb.a22r3.b1..1',
#  'drift_432',
#  'mb.a22r3.b1',
#  'drift_433',
#  'mb.a22r3.b1..2',
#  'drift_434',
#  'mcs.a22r3.b1',
#  'drift_435',
#  'mb.b22r3.b1..1',
#  'drift_436',
#  'mb.b22r3.b1',
#  'drift_437',
#  'mb.b22r3.b1..2',
#  'drift_438',
#  'mcs.b22r3.b1',
#  'drift_439',
#  'mco.b22r3.b1',
#  'drift_440',
#  'mcd.b22r3.b1',
#  'drift_441',
#  'mb.c22r3.b1..1',
#  'drift_442',
#  'mb.c22r3.b1',
#  'drift_443',
#  'mb.c22r3.b1..2',
#  'drift_444',
#  'mcs.c22r3.b1',
#  'drift_445',
#  'bpm.22r3.b1',
#  'drift_446',
#  'mo.22r3.b1',
#  'drift_447',
#  'mq.22r3.b1..1',
#  'drift_448',
#  'mq.22r3.b1',
#  'drift_449',
#  'mq.22r3.b1..2',
#  'drift_450',
#  'ms.22r3.b1',
#  'drift_451',
#  'mcbv.22r3.b1',
#  'drift_452',
#  'mb.a23r3.b1..1',
#  'drift_453',
#  'mb.a23r3.b1',
#  'drift_454',
#  'mb.a23r3.b1..2',
#  'drift_455',
#  'mcs.a23r3.b1',
#  'drift_456',
#  'mco.23r3.b1',
#  'drift_457',
#  'mcd.23r3.b1',
#  'drift_458',
#  'mb.b23r3.b1..1',
#  'drift_459',
#  'mb.b23r3.b1',
#  'drift_460',
#  'mb.b23r3.b1..2',
#  'drift_461',
#  'mcs.b23r3.b1',
#  'drift_462',
#  'mb.c23r3.b1..1',
#  'drift_463',
#  'mb.c23r3.b1',
#  'drift_464',
#  'mb.c23r3.b1..2',
#  'drift_465',
#  'mcs.c23r3.b1',
#  'drift_466',
#  'bpm.23r3.b1',
#  'drift_467',
#  'mqs.23r3.b1',
#  'drift_468',
#  'mq.23r3.b1..1',
#  'drift_469',
#  'mq.23r3.b1',
#  'drift_470',
#  'mq.23r3.b1..2',
#  'drift_471',
#  'ms.23r3.b1',
#  'drift_472',
#  'mcbh.23r3.b1',
#  'drift_473',
#  'mco.a24r3.b1',
#  'drift_474',
#  'mcd.a24r3.b1',
#  'drift_475',
#  'mb.a24r3.b1..1',
#  'drift_476',
#  'mb.a24r3.b1',
#  'drift_477',
#  'mb.a24r3.b1..2',
#  'drift_478',
#  'mcs.a24r3.b1',
#  'drift_479',
#  'mb.b24r3.b1..1',
#  'drift_480',
#  'mb.b24r3.b1',
#  'drift_481',
#  'mb.b24r3.b1..2',
#  'drift_482',
#  'mcs.b24r3.b1',
#  'drift_483',
#  'mco.b24r3.b1',
#  'drift_484',
#  'mcd.b24r3.b1',
#  'drift_485',
#  'mb.c24r3.b1..1',
#  'drift_486',
#  'mb.c24r3.b1',
#  'drift_487',
#  'mb.c24r3.b1..2',
#  'drift_488',
#  'mcs.c24r3.b1',
#  'drift_489',
#  'bpm.24r3.b1',
#  'drift_490',
#  'mo.24r3.b1',
#  'drift_491',
#  'mq.24r3.b1..1',
#  'drift_492',
#  'mq.24r3.b1',
#  'drift_493',
#  'mq.24r3.b1..2',
#  'drift_494',
#  'ms.24r3.b1',
#  'drift_495',
#  'mcbv.24r3.b1',
#  'drift_496',
#  'mb.a25r3.b1..1',
#  'drift_497',
#  'mb.a25r3.b1',
#  'drift_498',
#  'mb.a25r3.b1..2',
#  'drift_499',
#  ...)

# %%
collider.lhcb2.elements  # Element objects
# Out:
# (Marker(_dummy=0),
#  Drift(length=21.029999999998836),
#  Multipole(_order=0, inv_factorial_order=1.0, length=1.7, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.4904999999998836),
#  Drift(length=0.0),
#  Drift(length=0.8712999999988824),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3135999999976775),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3136000000013155),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00053513], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00053513], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00053513], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00053513], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3135999999976775),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3135999999976775),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.7767999999996391),
#  Drift(length=0.0),
#  Drift(length=3.776799999999639),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00096448], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9472999999998137),
#  Drift(length=0.0),
#  Drift(length=4.134500000000116),
#  Drift(length=0.0),
#  Drift(length=5.819999999999709),
#  Drift(length=0.0),
#  Drift(length=30.479999999999563),
#  Drift(length=0.0),
#  Drift(length=2.0),
#  Drift(length=0.0),
#  Drift(length=31.15299999999843),
#  Multipole(_order=0, inv_factorial_order=1.0, length=1.7, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.540500000002794),
#  Drift(length=0.0),
#  Drift(length=0.8712999999952444),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3136000000013155),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3135999999976775),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00075531], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00075531], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00075531], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00075531], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3135999999976775),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=5.553599999999278),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3135999999976775),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.4144000000014785),
#  Marker(_dummy=0),
#  Drift(length=0.4144000000014785),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.828799999999319),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.777, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00101315], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.372299999999086),
#  Drift(length=0.0),
#  Drift(length=2.3395000000018626),
#  Multipole(_order=0, inv_factorial_order=1.0, length=3.4, hxl=-0.0001887290780855326, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00018873], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.234999999996944),
#  Multipole(_order=0, inv_factorial_order=1.0, length=3.4, hxl=-0.0001887290780855326, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00018873], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.235000000000582),
#  Multipole(_order=0, inv_factorial_order=1.0, length=3.4, hxl=-0.0001887290780855326, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00018873], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=14.076500000002852),
#  Drift(length=0.0),
#  Drift(length=3.9464999999981956),
#  Multipole(_order=0, inv_factorial_order=1.0, length=3.4, hxl=0.0001887290780855326, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.00018873], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.235000000000582),
#  Multipole(_order=0, inv_factorial_order=1.0, length=3.4, hxl=0.0001887290780855326, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.00018873], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.235000000000582),
#  Multipole(_order=0, inv_factorial_order=1.0, length=3.4, hxl=0.0001887290780855326, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.00018873], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.326000000000931),
#  Drift(length=0.0),
#  Drift(length=0.9366666666646779),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5883333333295013),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5883333333331393),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5883333333295013),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.589333333333343),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5893333333297051),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00160681], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8576666666667734),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.9, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=34.125),
#  Drift(length=0.0),
#  Drift(length=10.600000000002183),
#  Drift(length=0.0),
#  Drift(length=9.61649999999645),
#  Drift(length=0.0),
#  Drift(length=2.1535000000003492),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.9, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8566666666665697),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00047391], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00047391], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9023333333316259),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.513666666669451),
#  Drift(length=0.0),
#  Drift(length=0.47299999999813735),
#  Marker(_dummy=0),
#  Drift(length=0.4059999999990396),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682733067),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827200286),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0015000000021245796),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.4099999999998545),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.9, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8566666666774836),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00172262], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00172262], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9023333333316259),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.513666666654899),
#  Drift(length=0.0),
#  Drift(length=0.8790000000153668),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.65758068273135),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682733067),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827091146),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0014999999984866008),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.3540000000029977),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.9, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8566666666920355),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.0000000e+00 -2.4359305e-06], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.0000000e+00 -2.4359305e-06], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5883333333295013),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.0000000e+00 -2.4359305e-06], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.0000000e+00 -2.4359305e-06], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9023333333316259),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.513666666643985),
#  Drift(length=0.0),
#  Drift(length=0.8800000000228465),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682733067),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.718080682792788),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0015000000021245796),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.4099999999998545),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.9, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8566666667029494),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00191167], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00191167], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9023333333352639),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.5136666666257952),
#  Drift(length=0.0),
#  Drift(length=0.8790000000408327),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.65758068273135),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682736705),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.65758068273135),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.718080682781874),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0014999999984866008),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=7.202349999999569),
#  Drift(length=0.0),
#  Drift(length=7.609349999998813),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.647, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.592999999953463),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.369, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.          0.         -0.04005655], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5786666666681413),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00221272], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.43333333333430346),
#  Marker(_dummy=0),
#  Drift(length=0.43333333333430346),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.65, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00221272], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9023333333316259),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.5136666667131067),
#  Drift(length=0.0),
#  Drift(length=0.47300000000177533),
#  Marker(_dummy=0),
#  Drift(length=0.40599999995174585),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682736705),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.65758068273135),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827673223),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0014999999984866008),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7499999999672582),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.8105806827115885),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.647, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5930000000225846),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.369, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.         0.05816472], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8616666666675883),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8680000000022119),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.16, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00048113], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.10666666666656965),
#  Marker(_dummy=0),
#  Drift(length=0.10666666666656965),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.16, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.00048113], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.6473333333087794),
#  Drift(length=0.0),
#  Drift(length=0.8790000000226428),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827527704),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0014999999984866008),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7499999999818101),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.4695806828312925),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827382185),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0014999999984866008),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0910000000003492),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.647, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5929999999971187),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.369, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.          0.         -0.04005655], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8616666666675883),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8679999999985739),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.16, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00076677], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.10666666666656965),
#  Marker(_dummy=0),
#  Drift(length=0.10666666666656965),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.16, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.00076677], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.6473333333378832),
#  Drift(length=0.0),
#  Drift(length=0.47300000000177533),
#  Marker(_dummy=0),
#  Drift(length=0.4059999999954016),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.65758068273135),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682733067),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827273045),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0014999999984866008),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7500000000109139),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.65758068273135),
# ...
#  Drift(length=0.8616666666675883),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8679999999985739),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.16, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.00000000e+00 6.09576916e-05], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.10666666666656965),
#  Marker(_dummy=0),
#  Drift(length=0.10666666666656965),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.16, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.00000000e+00 6.09576916e-05], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.647333333377901),
#  Drift(length=0.0),
#  Drift(length=0.8789999999571592),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682733067),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827600463),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0015000000021245796),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7499999999708962),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.810580682802538),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.647, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5930000000298605),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.369, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.         0.05816472], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8616666666675883),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9776666666657547),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.32, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7509999999710999),
#  Drift(length=0.0),
#  Drift(length=0.8790000000299187),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827454944),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0015000000021245796),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7499999999854481),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.65758068273135),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.4695806828349305),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827345805),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0014999999984866008),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0910000000003492),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.647, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5929999999971187),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.369, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.          0.         -0.04005655], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8616666666675883),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.01357201], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9746666666687815),
#  Multipole(_order=1, inv_factorial_order=1.0, length=0.32, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0.], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7540000000008149),
#  Drift(length=0.0),
#  Drift(length=0.8789999999971769),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.469580682733067),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827200286),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0015000000021245796),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7500000000109139),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.657580682734988),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=3.81058068276252),
#  Multipole(_order=0, inv_factorial_order=1.0, length=0.647, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.5929999999716529),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.369, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.         0.         0.05816472], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.8616666666675883),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=1.0333333333328483),
#  Marker(_dummy=0),
#  Drift(length=1.0333333333328483),
#  Multipole(_order=1, inv_factorial_order=1.0, length=1.55, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.         -0.01353104], ksl=[0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.9776666666657547),
#  Multipole(_order=3, inv_factorial_order=0.16666666666666666, length=0.32, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0. 0.], ksl=[0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.7510000000293076),
#  Drift(length=0.0),
#  Drift(length=0.8789999999717111),
#  Multipole(_order=2, inv_factorial_order=0.5, length=0.11, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0. 0. 0.], ksl=[0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.6575806828332134),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=4.766666666666424),
#  Marker(_dummy=0),
#  Drift(length=4.766666666666424),
#  Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=-0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[-0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=2.7180806827054766),
#  Multipole(_order=4, inv_factorial_order=0.041666666666666664, length=0.066, hxl=0.0, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[ 0.  0.  0.  0. -0.], ksl=[0. 0. 0. 0. 0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0)),
#  Drift(length=0.0015000000021245796),
#  ...)

# %% [markdown]
# ### Access the properties of individual elements

# %%
collider.lhcb1['ip1']  # A marker element at one of the collision points (ATLAS experiment)
# Out:
# Marker(_dummy=0)

# %%
collider.lhcb1['mb.b18l3.b1..1']  # A bending magnet
# Out:
# Multipole(_order=0, inv_factorial_order=1.0, length=7.15, hxl=0.002549994037004702, hyl=0.0, radiation_flag=0, delta_taper=0.0, knl=[0.00254999], ksl=[0.], _internal_record_id=RecordIdentifier(buffer_id=0, offset=0))

# %%
collider.lhcb1['mb.b18l3.b1..1'].to_dict()  # We can view its properties
# Out:
# {'__class__': 'Multipole',
#  '_order': 0,
#  'inv_factorial_order': 1.0,
#  'length': 7.15,
#  'hxl': 0.002549994037004702,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'delta_taper': 0.0,
#  'knl': array([0.00254999]),
#  'ksl': array([0.])}

# %%
# A quadrupole
collider.lhcb1['mqwa.a4l3.b1..2']
collider.lhcb1['mqwa.a4l3.b1..2'].to_dict()
# Out:
# {'__class__': 'Multipole',
#  '_order': 1,
#  'inv_factorial_order': 1.0,
#  'length': 0.777,
#  'hxl': 0.0,
#  'hyl': 0.0,
#  'radiation_flag': 0,
#  'delta_taper': 0.0,
#  'knl': array([0.        , 0.00096448]),
#  'ksl': array([0., 0.])}

# %% [markdown]
# ### Twiss
#
# Compute orbit, optics and other quantities of interest.

# %%
# Compute the twiss for the first beamline
twb1 = collider.lhcb1.twiss()

# Compute the twiss for the second beamline, and reverse it to have the two in the same reference frame
twb2 = collider.lhcb2.twiss().reverse()

# %% [markdown]
# ### Measure the tune

# %%
num_turns = 500

p_co = twb1.particle_on_co.copy()

collider.lhcb1.track(p_co, num_turns=num_turns, turn_by_turn_monitor=True)
mon_co = collider.lhcb1.record_last_track

p1 = twb1.particle_on_co.copy()
p1.x += 0.1e-3
p1.y += 0.2e-3
collider.lhcb1.track(p1, num_turns=num_turns, turn_by_turn_monitor=True)
mon1 = collider.lhcb1.record_last_track

# %%
# Plot turn-by-turn data
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Turn-by-turn data')
spx.plot(mon_co.x.T)
spx.plot(mon1.x.T)
spy.plot(mon_co.y.T)
spy.plot(mon1.y.T)
spy.set_xlabel('Turn')
spx.set_ylabel('x [m]')
spy.set_ylabel('y [m]')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'y [m]')

# %%
# Plot the transverse spectrum
fig, (spx, spy) = plt.subplots(nrows=2, ncols=1, sharex=True)
fig.suptitle('Transverse spectrum')
freq_axis = np.fft.rfftfreq(n=num_turns)
spx.plot(freq_axis, np.abs(np.fft.rfft(mon1.x[0, :])))
spy.plot(freq_axis, np.abs(np.fft.rfft(mon1.y[0, :])))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, (spbet, spco) = plt.subplots(nrows=2, ncols=1, sharex=True)
tw = twb1
spbet.plot(tw['s'], tw['betx'])
spbet.plot(tw['s'], tw['bety'])
spbet.set_ylim(bottom=0)
spco.plot(tw['s'], tw['x'], label='x')
spco.plot(tw['s'], tw['y'], label='y')
spco.legend()
spbet.set_ylabel(r'$\beta_{x,y}$ [m]')
spco.set_ylabel(r'(Closed orbit)$_{x,y}$ [m]')

# vertical lines at IPs with labels next to them at the top of the plot
for ip in ['ip1', 'ip2', 'ip5', 'ip8']:
    spbet.axvline(x=tw['s', ip], color='k', alpha=0.2, linestyle='--')
    spco.axvline(x=tw['s', ip], color='k', alpha=0.2, linestyle='--')


fig.suptitle(
    r'$q_x$ = ' f'{tw["qx"]:.5f}' r' $q_y$ = ' f'{tw["qy"]:.5f}' '\n'
    r"$Q'_x$ = " f'{tw["dqx"]:.2f}' r" $Q'_y$ = " f'{tw["dqy"]:.2f}'
    r' $\gamma_{tr}$ = '  f'{1/np.sqrt(tw["momentum_compaction_factor"]):.2f}'
)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0.98, "$q_x$ = 62.31000 $q_y$ = 60.32001\n$Q'_x$ = 2.04 $Q'_y$ = 3.05 $\\gamma_{tr}$ = 53.54")

# %% [markdown]
# ### Survey

# %%
# Run the survey
sv1 = collider.lhcb1.survey(element0='ip1')
sv2 = collider.lhcb2.survey(element0='ip1').reverse()

# %%
# Draw the plot
offset = 200.

twb1_ir1 = twb1.rows[twb1['s', 'ip1']-offset:twb1['s', 'ip1']+offset:'s']
svb1_ir1 = sv1.rows[sv1['s', 'ip1']-offset:sv1['s', 'ip1']+offset:'s']

twb2_ir1 = twb2.rows[twb2['s', 'ip1']-offset:twb2['s', 'ip1']+offset:'s']
svb2_ir1 = sv2.rows[sv2['s', 'ip1']-offset:sv2['s', 'ip1']+offset:'s']

fig, ax = plt.subplots()
fig.suptitle('IP1 (ATLAS experiment)')
ax.plot(svb1_ir1.Z, svb1_ir1.X, label='x', linestyle='--', color='b')
ax.plot(svb2_ir1.Z, svb2_ir1.X, label='y', linestyle='--', color='r')

ax.plot(svb1_ir1.Z, svb1_ir1.X + twb1_ir1.x, label='x', linestyle='-', color='b')
ax.plot(svb2_ir1.Z, svb2_ir1.X + twb2_ir1.x, label='y', linestyle='-', color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# See the whole ring
fig, ax = plt.subplots()
fig.suptitle('LHC Ring')
ax.set_box_aspect(1)
ax.plot(sv1.Z, sv1.X, label='x', linestyle='--', color='b')
ax.plot(sv2.Z, sv2.X, label='y', linestyle='--', color='r')

ax.plot(sv1.Z, sv1.X + twb1.x, label='x', linestyle='-', color='b')
ax.plot(sv2.Z, sv2.X + twb2.x, label='y', linestyle='-', color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
